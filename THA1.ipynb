# %%
import pandas as pd

sampleWorldBank = pd.read_csv("WorldBank.csv")
print(sampleWorldBank)
print(list(sampleWorldBank))
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFG                  South Asia           Low income
# 2            AGO          Sub-Saharan Africa  Lower middle income
# 3            ALB       Europe & Central Asia  Upper middle income
# 4            AND       Europe & Central Asia          High income
# 5            ARB                         NaN                  NaN
# 6            ARE  Middle East & North Africa          High income
# 7            ARG   Latin America & Caribbean          High income
# 8            ARM       Europe & Central Asia  Upper middle income
# 9            ASM         East Asia & Pacific  Upper middle income
# 10           ATG   Latin America & Caribbean          High income
# 11           AUS         East Asia & Pacific          High income
# 12           AUT       Europe & Central Asia          High income
# ...

# %%
country_incomegroup = sampleWorldBank[['TableName','IncomeGroup']]
country_incomegroup
# Out:
#                                    TableName          IncomeGroup
# 0                                      Aruba          High income
# 1                                Afghanistan           Low income
# 2                                     Angola  Lower middle income
# 3                                    Albania  Upper middle income
# 4                                    Andorra          High income
# 5                                 Arab World                  NaN
# 6                       United Arab Emirates          High income
# 7                                  Argentina          High income
# 8                                    Armenia  Upper middle income
# 9                             American Samoa  Upper middle income
# 10                       Antigua and Barbuda          High income
# 11                                 Australia          High income
# 12                                   Austria          High income
# ...

# %%
sampleWVSJordan14 = pd.read_excel("WVS_Jordan_2014.xlsx")
print(sampleWVSJordan14)
print(list(sampleWVSJordan14))
# Out:
#        V1: Wave V2: Country Code V2A: Country/regions [with split ups]  \
# 0     2010-2013           Jordan                                Jordan
# 1     2010-2013           Jordan                                Jordan
# 2     2010-2013           Jordan                                Jordan
# 3     2010-2013           Jordan                                Jordan
# 4     2010-2013           Jordan                                Jordan
# 5     2010-2013           Jordan                                Jordan
# 6     2010-2013           Jordan                                Jordan
# 7     2010-2013           Jordan                                Jordan
# 8     2010-2013           Jordan                                Jordan
# 9     2010-2013           Jordan                                Jordan
# 10    2010-2013           Jordan                                Jordan
# 11    2010-2013           Jordan                                Jordan
# ...

# %%
jordan14_happiness_satisfaction = sampleWVSJordan14[['V10: Feeling of happiness','V23: Satisfaction with your life']]
print(jordan14_happiness_satisfaction)
# Out:
#      V10: Feeling of happiness V23: Satisfaction with your life
# 0             Not at all happy                                5
# 1               Not very happy                                4
# 2               Not very happy                                6
# 3                 Rather happy                                7
# 4                 Rather happy                                7
# 5               Not very happy                                4
# 6                 Rather happy                                8
# 7                 Rather happy                                8
# 8                 Rather happy                                8
# 9                 Rather happy                                7
# 10              Not very happy                                6
# 11                Rather happy                                3
# 12                Rather happy                                7
# 13              Not very happy                                6
# ...

# %%
sampleHDIJordan = pd.read_csv("HDI_Jordan_Country_Profile.csv")
print(sampleHDIJordan)
# Out:
#                                                 Jordan Unnamed: 1
# 0                     Life expectancy at birth (years)       74.5
# 1      Adult mortality rate, female (per 1,000 people)         91
# 2        Adult mortality rate, male (per 1,000 people)        126
# 3    Child malnutrition, stunting (moderate or seve...        7.8
# 4                Current health expenditure (% of GDP)        6.3
# 5             Life expectancy at birth, female (years)       76.3
# 6               Life expectancy at birth, male (years)       72.8
# 7                                Life expectancy index      0.838
# 8                 HIV prevalence, adult (% ages 15-49)        0.1
# 9       Mortality rate, infant (per 1,000 live births)       15.1
# 10   Infants lacking immunization, DPT (% of one-ye...          1
# 11   Infants lacking immunization, measles (% of on...          7
# 12        Malaria incidence (per 1,000 people at risk)        n.a
# ...

# %%
sampleWVSJordan07 = pd.read_excel("WVS_Jordan_2007.xlsx")
print(sampleWVSJordan07)
print(list(sampleWVSJordan07))
# Out:
#      V1: wave number V1A: split oecd V1B: split ballot V2: Country/Region  \
# 0          2005-2007        non-oecd    Not applicable             Jordan
# 1          2005-2007        non-oecd    Not applicable             Jordan
# 2          2005-2007        non-oecd    Not applicable             Jordan
# 3          2005-2007        non-oecd    Not applicable             Jordan
# 4          2005-2007        non-oecd    Not applicable             Jordan
# 5          2005-2007        non-oecd    Not applicable             Jordan
# 6          2005-2007        non-oecd    Not applicable             Jordan
# 7          2005-2007        non-oecd    Not applicable             Jordan
# 8          2005-2007        non-oecd    Not applicable             Jordan
# 9          2005-2007        non-oecd    Not applicable             Jordan
# 10         2005-2007        non-oecd    Not applicable             Jordan
# 11         2005-2007        non-oecd    Not applicable             Jordan
# ...

# %%
jordan07_happiness_satisfaction = sampleWVSJordan07[['V10: Feeling of happiness','V22: How satisfied are you with your life']]
print(jordan07_happiness_satisfaction)
# Out:
#      V10: Feeling of happiness V22: How satisfied are you with your life
# 0                  Quite happy                                 Satisfied
# 1                  Quite happy                                         6
# 2                  Quite happy                                         7
# 3                  Quite happy                                         9
# 4                  Quite happy                                         8
# 5               Not very happy                                         8
# 6                  Quite happy                                         9
# 7                  Quite happy                                 Satisfied
# 8                  Quite happy                                         9
# 9                  Quite happy                                         8
# 10                 Quite happy                                         5
# 11                 Quite happy                                 Satisfied
# ...

# %%
jordan07_happiness_leisure = sampleWVSJordan07[['V10: Feeling of happiness','V6: Leisure time']]
print(jordan07_happiness_leisure)
# Out:
#      V10: Feeling of happiness      V6: Leisure time
# 0                  Quite happy      Rather important
# 1                  Quite happy        Very important
# 2                  Quite happy        Very important
# 3                  Quite happy    Not very important
# 4                  Quite happy    Not very important
# 5               Not very happy        Very important
# 6                  Quite happy      Rather important
# 7                  Quite happy    Not very important
# 8                  Quite happy        Very important
# 9                  Quite happy    Not very important
# 10                 Quite happy      Rather important
# 11                 Quite happy    Not very important
# 12              Not very happy        Very important
# 13                 Quite happy      Rather important
# 14            Not at all happy    Not very important
# 15            Not at all happy      Rather important
# 16                  Very happy    Not very important
# ...

# %%
jordan07_happiness_satisfaction_leisure = jordan07_happiness_satisfaction.merge(jordan07_happiness_leisure, on='V10: Feeling of happiness', how="inner")
print(jordan07_happiness_satisfaction_leisure)
# Out:
#        V10: Feeling of happiness V22: How satisfied are you with your life  \
# 0                    Quite happy                                 Satisfied
# 1                    Quite happy                                 Satisfied
# 2                    Quite happy                                 Satisfied
# 3                    Quite happy                                 Satisfied
# 4                    Quite happy                                 Satisfied
# 5                    Quite happy                                 Satisfied
# 6                    Quite happy                                 Satisfied
# 7                    Quite happy                                 Satisfied
# 8                    Quite happy                                 Satisfied
# 9                    Quite happy                                 Satisfied
# 10                   Quite happy                                 Satisfied
# ...
